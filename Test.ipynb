# %% [markdown]
# install a conda package
# ```
# import sys
# !conda install --yes --prefix {sys.prefix} numpy
# ```
# install a pip package
# ```
# # Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install numpy
# ```

# %%
import sys
# !{sys.executable} -m  pip install fastai duckduckgo_search
# !{sys.executable} -m pip install nbdev
# Out:
# Requirement already satisfied: fastai in c:\programdata\anaconda3\lib\site-packages (2.7.13)
# Requirement already satisfied: duckduckgo_search in c:\programdata\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: pip in c:\programdata\anaconda3\lib\site-packages (from fastai) (23.2.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from fastai) (23.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\programdata\anaconda3\lib\site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.5.29)
# Requirement already satisfied: torchvision>=0.11 in c:\programdata\anaconda3\lib\site-packages (from fastai) (0.16.2)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from fastai) (3.7.1)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.5.3)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from fastai) (2.31.0)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from fastai) (6.0)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\programdata\anaconda3\lib\site-packages (from fastai) (9.4.0)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.3.0)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.10.1)
# Requirement already satisfied: spacy<4 in c:\programdata\anaconda3\lib\site-packages (from fastai) (3.7.2)
# Requirement already satisfied: torch<2.2,>=1.10 in c:\programdata\anaconda3\lib\site-packages (from fastai) (2.1.2)
# Requirement already satisfied: click>=8.1.7 in c:\programdata\anaconda3\lib\site-packages (from duckduckgo_search) (8.1.7)
# Requirement already satisfied: lxml>=4.9.3 in c:\programdata\anaconda3\lib\site-packages (from duckduckgo_search) (4.9.4)
# Requirement already satisfied: curl-cffi>=0.5.10 in c:\programdata\anaconda3\lib\site-packages (from duckduckgo_search) (0.5.10)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=8.1.7->duckduckgo_search) (0.4.6)
# Requirement already satisfied: cffi>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from curl-cffi>=0.5.10->duckduckgo_search) (1.15.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (4.65.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (2.5.3)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (3.1.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (68.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (2023.11.17)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch<2.2,>=1.10->fastai) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch<2.2,>=1.10->fastai) (4.7.1)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch<2.2,>=1.10->fastai) (1.11.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch<2.2,>=1.10->fastai) (3.1)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch<2.2,>=1.10->fastai) (2023.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->fastai) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->fastai) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->fastai) (2.2.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12.0->curl-cffi>=0.5.10->duckduckgo_search) (2.21)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.14.6)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\programdata\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\programdata\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<4->fastai) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch<2.2,>=1.10->fastai) (1.3.0)
# Collecting nbdev
#   Obtaining dependency information for nbdev from https://files.pythonhosted.org/packages/45/44/2148be2391edd62b8c88c2114f380141b72276901a53d590be9f769a68e4/nbdev-2.3.13-py3-none-any.whl.metadata
#   Downloading nbdev-2.3.13-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ipywidgets<=8.0.4 in c:\programdata\anaconda3\lib\site-packages (from nbdev) (8.0.4)
# Requirement already satisfied: fastcore>=1.5.27 in c:\programdata\anaconda3\lib\site-packages (from nbdev) (1.5.29)
# Collecting execnb>=0.1.4 (from nbdev)
#   Downloading execnb-0.1.5-py3-none-any.whl (13 kB)
# Collecting astunparse (from nbdev)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting ghapi>=1.0.3 (from nbdev)
#   Obtaining dependency information for ghapi>=1.0.3 from https://files.pythonhosted.org/packages/60/71/064560201c434c22c9f395878ba0f21f9ede8169e61c1a109f26a377bd5e/ghapi-1.0.4-py3-none-any.whl.metadata
#   Downloading ghapi-1.0.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: watchdog in c:\programdata\anaconda3\lib\site-packages (from nbdev) (2.1.6)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from nbdev) (2.0.5)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\lib\site-packages (from nbdev) (6.0)
# Requirement already satisfied: ipython in c:\programdata\anaconda3\lib\site-packages (from execnb>=0.1.4->nbdev) (8.12.0)
# Requirement already satisfied: pip in c:\programdata\anaconda3\lib\site-packages (from fastcore>=1.5.27->nbdev) (23.2.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from fastcore>=1.5.27->nbdev) (23.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets<=8.0.4->nbdev) (6.19.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets<=8.0.4->nbdev) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets<=8.0.4->nbdev) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets<=8.0.4->nbdev) (3.0.5)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from asttokens->nbdev) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse->nbdev) (0.38.4)
# Requirement already satisfied: comm>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (1.5.6)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (6.3.2)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython->execnb>=0.1.4->nbdev) (0.2.0)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython->execnb>=0.1.4->nbdev) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython->execnb>=0.1.4->nbdev) (0.18.1)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython->execnb>=0.1.4->nbdev) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\programdata\anaconda3\lib\site-packages (from ipython->execnb>=0.1.4->nbdev) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from ipython->execnb>=0.1.4->nbdev) (2.15.1)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from ipython->execnb>=0.1.4->nbdev) (0.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython->execnb>=0.1.4->nbdev) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython->execnb>=0.1.4->nbdev) (0.8.3)
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (2.8.2)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->execnb>=0.1.4->nbdev) (0.2.5)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev) (0.8.3)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev) (0.2.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (305.1)
# Downloading nbdev-2.3.13-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.1 kB ? eta -:--:--
#    ------------------ --------------------- 30.7/66.1 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 66.1/66.1 kB 886.6 kB/s eta 0:00:00
# Downloading ghapi-1.0.4-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.7 kB ? eta -:--:--
#    ---------------------------------------- 58.7/58.7 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: astunparse, ghapi, execnb, nbdev
# Successfully installed astunparse-1.6.3 execnb-0.1.5 ghapi-1.0.4 nbdev-2.3.13

# %%
from duckduckgo_search import ddg_images
from fastcore.all import *

def search_images(term, max_images=30):
    print(f"Searching for '{term}'")
    return L(ddg_images(term, max_results=max_images)).itemgot('image')

# %%
urls = search_images('sexy girls', max_images=1)
urls[0]
# Out:
# Searching for 'sexy girls'
# 'http://photos.theworldbeast.com/wp-content/uploads/2017/03/hot-girls-4.jpg'

# %%
from fastdownload import download_url
dest="bird.jpg"
download_url(urls[0],dest,show_progress=False)
# Out:
# Path('bird.jpg')

# %%
from fastai.vision.all import *
im=Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=209x256>

# %%
doc(im.to_thumb)
# Out:
# <hr/>
# <h3>Image.to_thumb</h3>
# <blockquote><pre><code>Image.to_thumb(h, w=None)</code></pre></blockquote><p>Same as `thumbnail`, but uses a copy</p>
